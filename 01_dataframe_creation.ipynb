# %%
data = [
    (101,"Amit Sharma",28,"Male","IT","Software Engineer",65000,"Delhi","2022-01-15"),
    (102,"Priya Singh",30,"Female","HR","HR Manager",75000,"Mumbai","2021-03-10"),
    (103,"Rahul Verma",26,"Male","IT","Data Analyst",55000,"Bangalore","2023-06-01"),
    (104,"Sneha Gupta",35,"Female","Finance","Accountant",70000,"Pune","2020-08-20"),
    (105,"Arjun Mehta",40,"Male","IT","Tech Lead",120000,"Hyderabad","2018-04-12"),
    (106,"Neha Jain",29,"Female","Sales","Sales Executive",50000,"Delhi","2022-11-05"),
    (107,"Vikram Patel",32,"Male","Sales","Sales Manager",90000,"Ahmedabad","2019-07-15"),
    (108,"Pooja Yadav",27,"Female","IT","Data Engineer",85000,"Bangalore","2023-02-01"),
    (109,"Karan Malhotra",31,"Male","Finance","Financial Analyst",78000,"Mumbai","2021-05-18"),
    (110,"Anjali Roy",24,"Female","HR","Recruiter",45000,"Kolkata","2024-01-10"),
    (111,"Mohit Kumar",38,"Male","Operations","Operations Manager",110000,"Chennai","2017-09-25"),
    (112,"Riya Kapoor",25,"Female","IT","QA Engineer",60000,"Noida","2023-08-15"),
    (113,"Deepak Mishra",33,"Male","Finance","Senior Accountant",85000,"Lucknow","2020-06-30"),
    (114,"Simran Kaur",29,"Female","Sales","Business Analyst",72000,"Chandigarh","2022-04-22"),
    (115,"Nitin Arora",41,"Male","IT","Architect",150000,"Gurgaon","2015-12-10")
]

columns_schema="emp_id integer, emp_name String, age integer, gender String, department String, designation String, salary integer, city String, joining_date String"

df=spark.createDataFrame(data,columns_schema)
df.show()
df.printSchema()
df.count()
